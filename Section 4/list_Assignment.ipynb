# %% [markdown]
# # Module 3: Data Structures Assignments
# ## Lesson 3.1: Lists
# ### Assignment 1: Creating and Accessing Lists
#
# Create a list of the first 20 positive integers. Print the list.
#
# ### Assignment 2: Accessing List Elements
#
# Print the first, middle, and last elements of the list created in Assignment 1.
#
# ### Assignment 3: List Slicing
#
# Print the first five elements, the last five elements, and the elements from index 5 to 15 of the list created in Assignment 1.
#
# ### Assignment 4: List Comprehensions
#
# Create a new list containing the squares of the first 10 positive integers using a list comprehension. Print the new list.
#
# ### Assignment 5: Filtering Lists
#
# Create a new list containing only the even numbers from the list created in Assignment 1 using a list comprehension. Print the new list.
#
# ### Assignment 6: List Methods
#
# Create a list of random numbers and sort it in ascending and descending order. Remove the duplicates from the list and print the modified list.
#
#
# ### Assignment 8: List of Dictionaries
#
# Create a list of dictionaries where each dictionary represents a student with keys 'name' and 'score'. Sort the list of dictionaries by the 'score' in descending order and print the sorted list.
#
#
#
# ### Assignment 10: Flattening a Nested List
#
# Write a function that takes a nested list and flattens it into a single list. Print the original and flattened lists.
#
# ### Assignment 11: List Manipulation
#
# Create a list of the first 10 positive integers. Remove the elements at indices 2, 4, and 6, and insert the element '99' at index 5. Print the modified list.
#
# ### Assignment 12: List Zipping
#
# Create two lists of the same length. Use the `zip` function to combine these lists into a list of tuples and print the result.
#
# ### Assignment 13: List Reversal
#
# Write a function that takes a list and returns a new list with the elements in reverse order. Print the original and reversed lists.
#
# ### Assignment 14: List Rotation
#
# Write a function that rotates a list by n positions. Print the original and rotated lists.
#
# ### Assignment 15: List Intersection
#
# Write a function that takes two lists and returns a new list containing only the elements that are present in both lists. Print the intersected list.

# %% [markdown]
# ### Assignment 7: Nested Lists
#
# Create a nested list representing a 3x3 matrix and print the matrix. Access and print the element at the second row and third column.

# %%
matrix = [
    [9, 8, 7],
    [6, 5, 4],
    [3, 2, 1],
]
print("Matrix")
for rows in matrix:
    print(rows)
print("The element at the second row and third column is",matrix[1][2])
# Out:
# Matrix
# [9, 8, 7]
# [6, 5, 4]
# [3, 2, 1]
# The element at the second row and third column is 4

# %% [markdown]
# ### Assignment 9: Matrix Transposition
#
# Write a function that takes a 3x3 matrix (nested list) as input and returns its transpose. Print the original and transposed matrices.

# %%
def transpose_matrix(matrix):
    transposed = [matrix[j][i] for j in range (len(matrix)) for i in range (len(matrix[0]))]
    return transposed

# Step 1: take number of rows and columns
rows = int(input("Enter number of rows: "))
cols = int(input("Enter number of columns: "))

# Step 2: create an empty list for the matrix
matrix = []

# Step 3: take row-wise input
for i in range(rows):
    print(f"\nEnter elements for row {i+1}:")
    row_input = input()  # take the whole row as a string
    row_elements = row_input.split()  # split string into parts like ['1','2','3']

    # convert each element from string to integer manually (without using map)
    row = []
    for j in range(len(row_elements)):
        row.append(int(row_elements[j]))

    matrix.append(row)  # add this row to the matrix

# Step 4: print the matrix
print("\nMatrix is:")
for r in matrix:
    print(r)

print("\nMatrix is:")
for row in matrix:
    print(row)


transposed = transpose_matrix(matrix)

print("Transposed matrix:")
for row in transposed:
    print(row)
# Out:
# Enter elements for row 1:
#
# Enter elements for row 2:
#
# Enter elements for row 3:
#
# Enter elements for row 4:
#
# Matrix is:
# [1, 2, 3]
# [3, 2, 1]
# [3, 2, 1]
# [3, 2, 1]
#
# Matrix is:
# [1, 2, 3]
# [3, 2, 1]
# [3, 2, 1]
# [3, 2, 1]
# Transposed matrix:
# 1
# 2
# 3
# 3
# 2
# 1
# 3
# 2
# 1
# 3
# 2
# 1

# %%
def transpose_matrix(matrix):
    num_rows = len(matrix)
    num_cols = len(matrix[0])
    
    # Create new rows from the old columns
    transposed = [[matrix[j][i] for j in range(num_rows)] for i in range(num_cols)]
    return transposed

rows = int(input("Enter number of rows: "))
cols = int(input("Enter number of columns: "))

matrix = []

for i in range(rows):
    print(f"\nEnter elements for row {i+1}:")
    row_input = input()  
    row_elements = row_input.split()  
    print(row_elements)

    # convert each element from string to integer manually
    row = []
    for j in range(len(row_elements)):
        row.append(int(row_elements[j]))

    matrix.append(row)  # add this row to the matrix

print("\nMatrix is:")
for r in matrix:
    print(r)

transposed = transpose_matrix(matrix)

print("\nTransposed matrix:")
for row in transposed:
    print(row)
# Out:
# Enter elements for row 1:
# ['2', '3']
#
# Enter elements for row 2:
# ['4', '5']
#
# Matrix is:
# [2, 3]
# [4, 5]
#
# Transposed matrix:
# [2, 4]
# [3, 5]
