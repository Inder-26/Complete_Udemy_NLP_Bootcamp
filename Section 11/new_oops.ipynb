# %%
class Person:
    pass

person = Person()
dir(Person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

person = Person('Krish', 34)
print(person)
# Out:
# <__main__.Person object at 0x0000014F2379A350>

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def __str__(self):
        return f"{self.name}, {self.age} years old"

person = Person('Krish', 34)
print(person)
# Out:
# Krish, 34 years old

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def __repr__(self):
        return f"Person(name={self.name}, age={self.age})"

person = Person('Krish', 34)
print(repr(person))
# Out:
# Person(name=Krish, age=34)

# %% [markdown]
# Custom Exception Handling

# %%
class Error(Exception):
    pass

class DOBException(Error):
    pass

# %%
year = int(input('Please enter your date of birth: '))
age = 2024 - year
if age >= 20 and age <= 30:
    print('The age is valid. You can apply for the exams.')
else:
    raise DOBException
# Out:
# The age is valid. You can apply for the exams.

# %%
try:
    year = int(input('Please enter your date of year: '))
    age = 2024 - year
    if age >= 20 and age <= 30:
        print('The age is valid. You can apply for the exams.')
    else:
        raise DOBException
except DOBException:
    print('Your age should be greater than 20 or less than 30.')
# Out:
# The age is valid. You can apply for the exams.
