# %%
import sqlite3

# %%
connection = sqlite3.connect('example.db')
connection

# %%
cursor = connection.cursor()

# %%
cursor.execute('''
Create Table If Not Exists employees(
    id Integer Primary Key,
    name text Not Null,
    age Integer,
    department text
    )
''')

connection.commit()
print("DB Created")
# Out:
# DB Created

# %%
cursor.execute('''
Select * from employees
''')

# %%
cursor.execute('''
INSERT INTO employees (name, age, department)
VALUES ('Ramesh', 28, 'Human Resources')
''')

cursor.execute('''
INSERT INTO employees (name, age, department)
VALUES ('Priya', 30, 'Marketing')
''')

cursor.execute('''
INSERT INTO employees (name, age, department)
VALUES ('Amit', 26, 'Software Development')
''')

cursor.execute('''
INSERT INTO employees (name, age, department)
VALUES ('Neha', 29, 'Sales')
''')

cursor.execute('''
INSERT INTO employees (name, age, department)
VALUES ('Vikram', 40, 'Operations')
''')

cursor.execute('''
INSERT INTO employees (name, age, department)
VALUES ('Sneha', 27, 'Customer Support')
''')

cursor.execute('''
INSERT INTO employees (name, age, department)
VALUES ('Arjun', 33, 'Cyber Security')
''')

cursor.execute('''
INSERT INTO employees (name, age, department)
VALUES ('Meera', 24, 'UI/UX Designing')
''')

cursor.execute('''
INSERT INTO employees (name, age, department)
VALUES ('Rahul', 31, 'Data Analytics')
''')

connection.commit()

# %%
cursor.execute('Select * from employees')
cursor.fetchall()
# Out:
# [(1, 'Ramesh', 28, 'Human Resources'),
#  (2, 'Priya', 30, 'Marketing'),
#  (3, 'Amit', 26, 'Software Development'),
#  (4, 'Neha', 29, 'Sales'),
#  (5, 'Vikram', 40, 'Operations'),
#  (6, 'Sneha', 27, 'Customer Support'),
#  (7, 'Arjun', 33, 'Cyber Security'),
#  (8, 'Meera', 24, 'UI/UX Designing'),
#  (9, 'Rahul', 31, 'Data Analytics'),
#  (10, 'Ramesh', 28, 'Human Resources'),
#  (11, 'Priya', 30, 'Marketing'),
#  (12, 'Amit', 26, 'Software Development'),
#  (13, 'Neha', 29, 'Sales'),
#  (14, 'Vikram', 40, 'Operations'),
#  (15, 'Sneha', 27, 'Customer Support'),
#  (16, 'Arjun', 33, 'Cyber Security'),
#  (17, 'Meera', 24, 'UI/UX Designing'),
#  (18, 'Rahul', 31, 'Data Analytics'),
#  (19, 'Ramesh', 28, 'Human Resources'),
#  (20, 'Priya', 30, 'Marketing'),
#  (21, 'Amit', 26, 'Software Development'),
#  (22, 'Neha', 29, 'Sales'),
#  (23, 'Vikram', 40, 'Operations'),
#  (24, 'Sneha', 27, 'Customer Support'),
#  (25, 'Arjun', 33, 'Cyber Security'),
# ...

# %%
## Update Data
cursor.execute('''
UPDATE employees
Set age = 34
where name  = 'Krish'
''')

connection.commit()

# %%
cursor.execute('Select * from employees')
entry=cursor.fetchall()
for row in entry:
    print(row)
# Out:
# (1, 'Ramesh', 28, 'Human Resources')
# (2, 'Priya', 30, 'Marketing')
# (3, 'Amit', 26, 'Software Development')
# (4, 'Neha', 29, 'Sales')
# (5, 'Vikram', 40, 'Operations')
# (6, 'Sneha', 27, 'Customer Support')
# (7, 'Arjun', 33, 'Cyber Security')
# (8, 'Meera', 24, 'UI/UX Designing')
# (9, 'Rahul', 31, 'Data Analytics')
# (10, 'Ramesh', 28, 'Human Resources')
# (11, 'Priya', 30, 'Marketing')
# (12, 'Amit', 26, 'Software Development')
# (13, 'Neha', 29, 'Sales')
# (14, 'Vikram', 40, 'Operations')
# (15, 'Sneha', 27, 'Customer Support')
# (16, 'Arjun', 33, 'Cyber Security')
# (17, 'Meera', 24, 'UI/UX Designing')
# (18, 'Rahul', 31, 'Data Analytics')
# (19, 'Ramesh', 28, 'Human Resources')
# (20, 'Priya', 30, 'Marketing')
# (21, 'Amit', 26, 'Software Development')
# (22, 'Neha', 29, 'Sales')
# (23, 'Vikram', 40, 'Operations')
# (24, 'Sneha', 27, 'Customer Support')
# (25, 'Arjun', 33, 'Cyber Security')
# (26, 'Meera', 24, 'UI/UX Designing')
# (27, 'Rahul', 31, 'Data Analytics')

# %%
cursor.execute("DELETE FROM employees WHERE name = 'Arjun'")
connection.commit()

# %%
cursor.execute('Select * from employees')
entry=cursor.fetchall()
for row in entry:
    print(row)
# Out:
# (1, 'Ramesh', 28, 'Human Resources')
# (2, 'Priya', 30, 'Marketing')
# (3, 'Amit', 26, 'Software Development')
# (4, 'Neha', 29, 'Sales')
# (5, 'Vikram', 40, 'Operations')
# (6, 'Sneha', 27, 'Customer Support')
# (8, 'Meera', 24, 'UI/UX Designing')
# (9, 'Rahul', 31, 'Data Analytics')
# (10, 'Ramesh', 28, 'Human Resources')
# (11, 'Priya', 30, 'Marketing')
# (12, 'Amit', 26, 'Software Development')
# (13, 'Neha', 29, 'Sales')
# (14, 'Vikram', 40, 'Operations')
# (15, 'Sneha', 27, 'Customer Support')
# (17, 'Meera', 24, 'UI/UX Designing')
# (18, 'Rahul', 31, 'Data Analytics')
# (19, 'Ramesh', 28, 'Human Resources')
# (20, 'Priya', 30, 'Marketing')
# (21, 'Amit', 26, 'Software Development')
# (22, 'Neha', 29, 'Sales')
# (23, 'Vikram', 40, 'Operations')
# (24, 'Sneha', 27, 'Customer Support')
# (26, 'Meera', 24, 'UI/UX Designing')
# (27, 'Rahul', 31, 'Data Analytics')

# %%
connection = sqlite3.connect('sales_data.db')
cursor = connection.cursor()
cursor.execute('''
CREATE TABLE IF NOT EXISTS sales (
    id INTEGER PRIMARY KEY,
    date TEXT NOT NULL,
    product TEXT NOT NULL,
    sales INTEGER,
    region TEXT
)''')

# %%
sales_data = [
    ('2023-01-01', 'ProductA', 100, 'North'),
    ('2023-01-02', 'ProductB', 150, 'South'),
    ('2023-01-03', 'ProductC', 200, 'East'),
    ('2023-01-04', 'ProductD', 250, 'West')
]
cursor.executemany(
    'INSERT INTO sales (date, product, sales, region) VALUES (?, ?, ?, ?)',
    sales_data
)
connection.commit()

# %%
cursor.execute('SELECT * FROM sales')
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, '2023-01-01', 'ProductA', 100, 'North')
# (2, '2023-01-02', 'ProductB', 150, 'South')
# (3, '2023-01-03', 'ProductC', 200, 'East')
# (4, '2023-01-04', 'ProductD', 250, 'West')

# %%
connection.close()
