# %% [markdown]
# # Module: SQLite3 Assignments
# ## Lesson: SQLite3
# ### Assignment 1: Creating and Connecting to a Database
#
# 1. Write a Python function to create a new SQLite3 database named `test.db`.

# %%
import sqlite3
def create_db():
    conn = sqlite3.connect('test.db_1')
    conn.close()
    print(f"Database created")
create_db()
# Out:
# Database created

# %% [markdown]
# 2. Write a Python function to create a table named `employees` with columns `id` (integer), `name` (text), `age` (integer), and `department` (text) in the `test.db` database.

# %%
def create_table():
    conn = sqlite3.connect('test.db_1')
    cursor = conn.cursor()
    cursor.execute('''
    CREATE TABLE IF Not Exists employees(
    id Integer Primary Key,
    name text Not Null,
    age integer Not Null,
    department text Not Null
    )
    
''')
    conn.close()
create_table()

# %% [markdown]
# ### Assignment 2: Inserting Data
#
# 1. Write a Python function to insert a new employee into the `employees` table.

# %%
def insert_employee(id, name, age, department):
    conn = sqlite3.connect('test.db_1')
    cursor = conn.cursor()
    cursor.execute('''
        INSERT INTO employees (id, name, age, department)
        VALUES (?, ?, ?, ?)
    ''', (id, name, age, department))
    conn.commit()
    conn.close()
    print("Employee inserted successfully.")

# Test the function
insert_employee(101, 'Inderjeet', 21, 'IT')
# Out:
# Employee inserted successfully.

# %% [markdown]
# 2. Insert at least 5 different employees into the `employees` table.

# %%
insert_employee(102, 'Ramesh', 22, 'Data Analytics')
insert_employee(103,'Arjun', 33, 'Cyber Security')
insert_employee(104,'Meera', 24, 'UI/UX Designing')
insert_employee(105,'Neha', 29, 'Sales')
insert_employee(106,'Priya', 30, 'Marketing')
# Out:
# Employee inserted successfully.
# Employee inserted successfully.
# Employee inserted successfully.
# Employee inserted successfully.
# Employee inserted successfully.

# %% [markdown]
# ### Assignment 3: Querying Data
#
# 1. Write a Python function to fetch and display all records from the `employees` table.

# %%
def employee_records():
    conn = sqlite3.connect('test.db_1')
    cursor = conn.cursor()
    records = cursor.execute('SELECT * FROM employees')
    for entry in records:
        print(entry)
    conn.close()
employee_records()
# Out:
# (101, 'Inderjeet', 21, 'IT')
# (102, 'Ramesh', 22, 'Data Analytics')
# (103, 'Arjun', 33, 'Cyber Security')
# (104, 'Meera', 24, 'UI/UX Designing')
# (105, 'Neha', 29, 'Sales')
# (106, 'Priya', 30, 'Marketing')

# %% [markdown]
# 2. Write a Python function to fetch and display all employees from a specific department.

# %%
def employee_specific_records():
    conn = sqlite3.connect('test.db_1')
    cursor = conn.cursor()
    records = cursor.execute("SELECT * FROM employees Where department='Sales'")
    for entry in records:
        print(entry)

employee_specific_records()
# Out:
# (105, 'Neha', 29, 'Sales')

# %% [markdown]
# ### Assignment 4: Updating Data
#
# 1. Write a Python function to update the department of an employee based on their `id`.

# %%
def update_record(employee_id, deparmtment):
    conn = sqlite3.connect('test.db_1')
    cursor = conn.cursor()
    cursor.execute('UPDATE employees SET department = ? WHERE id = ?',(deparmtment, employee_id))
    conn.commit()
    conn.close()
    print("Record updated successfully.")
update_record(105, 'Customer Support')
# Out:
# Record updated successfully.

# %% [markdown]
# 2. Update the department of at least 2 employees and display the updated records.

# %%
update_record(101, 'Prodcut Manager')
update_record(104, 'Full Stack Developer')
# Out:
# Record updated successfully.
# Record updated successfully.

# %% [markdown]
# ### Assignment 5: Deleting Data
#
# 1. Write a Python function to delete an employee from the `employees` table based on their `id`.

# %%
def delete_record(employee_id):
    conn = sqlite3.connect('test.db_1')
    cursor = conn.cursor()
    cursor.execute('DELETE FROM employees WHERE id = ?',(employee_id,))
    conn.commit()
    conn.close()
    print("Record deleted successfully.")
delete_record(103)
# Out:
# Record deleted successfully.

# %% [markdown]
# 2. Delete at least 1 employee and display the remaining records.

# %%
delete_record(101)
employee_records()
insert_employee(101, 'Inderjeet', 21, 'IT')
insert_employee(103,'Pinki', 24, 'UI/UX Designing')
# Out:
# Record deleted successfully.
# (104, 'Meera', 24, 'Full Stack Developer')
# (105, 'Neha', 29, 'Customer Support')
# (106, 'Priya', 30, 'Marketing')
# Employee inserted successfully.
# Employee inserted successfully.

# %% [markdown]
# ### Assignment 6: Advanced Queries
#
# 1. Write a Python function to fetch and display employees older than a certain age.

# %%
def display_age(age_limit):
    conn = sqlite3.connect('test.db_1')
    cursor = conn.cursor()
    cursor.execute('SeLECT * FROM employees WHERE age > ?',(age_limit,))
    records = cursor.fetchall()
    conn.close()
    for record in records:
        print(record)
display_age(24)
# Out:
# (105, 'Neha', 29, 'Customer Support')
# (106, 'Priya', 30, 'Marketing')

# %% [markdown]
# 2. Write a Python function to fetch and display employees whose names start with a specific letter.

# %%
def fetch_employees_name_starts_with(letter):
    conn = sqlite3.connect('test.db_1')
    cursor = conn.cursor()
    cursor.execute('SELECT * FROM employees WHERE name LIKE ?', (letter + '%',))
    records = cursor.fetchall()
    conn.close()
    for record in records:
        print(record)

# Test the function
fetch_employees_name_starts_with('P')
# Out:
# (103, 'Pinki', 24, 'UI/UX Designing')
# (106, 'Priya', 30, 'Marketing')

# %% [markdown]
# ### Assignment 7: Handling Transactions
#
# 1. Write a Python function to insert multiple employees into the `employees` table in a single transaction. Ensure that if any insertion fails, none of the insertions are committed.

# %%
employee_records()
def multiple_employee_entry(employees):
    conn = sqlite3.connect('test.db_1')
    cursor = conn.cursor()
    try:
        cursor.executemany('''
            INSERT INTO employees (id, name, age, department)
            VALUES (?, ?, ?, ?)
        ''', employees)
        conn.commit()
        print("All employees inserted successfully.")
    except Exception as e:
        conn.rollback()
        print("Error occurred, transaction rolled back.")
        print(e)
    finally:
        conn.close()
employees=[
    (102,'Shivam', '25', 'DevOps'),
    (107, 'Anjali', 28, 'HR'),
    (108, 'Vikram', 32, 'Finance'),
    (109, 'Sonal', 27, 'Legal'),
    (102, 'Karan', 26, 'R&D')
    ]
multiple_employee_entry(employees)
employee_records()
# Out:
# (101, 'Inderjeet', 21, 'IT')
# (102, 'Shivam', 25, 'DevOps')
# (103, 'Pinki', 24, 'UI/UX Designing')
# (104, 'Meera', 24, 'Full Stack Developer')
# (105, 'Neha', 29, 'Customer Support')
# (106, 'Priya', 30, 'Marketing')
# (107, 'Anjali', 28, 'HR')
# (108, 'Vikram', 32, 'Finance')
# (109, 'Sonal', 27, 'Legal')
# (1020, 'Karan', 26, 'R&D')
# Error occurred, transaction rolled back.
# UNIQUE constraint failed: employees.id
# (101, 'Inderjeet', 21, 'IT')
# (102, 'Shivam', 25, 'DevOps')
# (103, 'Pinki', 24, 'UI/UX Designing')
# (104, 'Meera', 24, 'Full Stack Developer')
# (105, 'Neha', 29, 'Customer Support')
# (106, 'Priya', 30, 'Marketing')
# (107, 'Anjali', 28, 'HR')
# (108, 'Vikram', 32, 'Finance')
# (109, 'Sonal', 27, 'Legal')
# (1020, 'Karan', 26, 'R&D')

# %% [markdown]
# 2. Write a Python function to update the age of multiple employees in a single transaction. Ensure that if any update fails, none of the updates are committed.

# %%
def update_multiple_age(updates):
    conn = sqlite3.connect('test.db_1')
    cursor = conn.cursor()
    try:
        cursor.executemany('''
            UPDATE employees
            SET age = ?
            WHERE id = ?
    ''',updates)
        conn.commit()
        print("All employees ages updated successfully.")
    except Exception as e:
        conn.rollback()
        print("Error Occured, transaction rolled back.")
        print(e)
    finally:
        conn.close()
updates = [
    (20,101),
    (21,102),
    (22,103)
]
update_multiple_age(updates)
# Out:
# All employees ages updated successfully.

# %% [markdown]
# ### Assignment 8: Creating Relationships
#
# 1. Create a new table named `departments` with columns `id` (integer) and `name` (text).

# %%
def create_departments_table():
    conn = sqlite3.connect('test.db_1')
    cursor = conn.cursor()
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS departments (
            id INTEGER PRIMARY KEY,
            name TEXT NOT NULL
        )
    ''')
    conn.commit()
    conn.close()
    print("Table 'departments' created successfully.")

# Test the function
create_departments_table()
# Out:
# Table 'departments' created successfully.

# %% [markdown]
# 2. Modify the `employees` table to include a foreign key referencing the `id` column in the `departments` table.

# %% [markdown]
# 3. Write a Python function to insert data into both the `departments` and `employees` tables, ensuring referential integrity.

# %% [markdown]
# ### Assignment 9: Indexing and Optimization
#
# 1. Create an index on the `name` column of the `employees` table.

# %% [markdown]
# 2. Write a Python function to fetch and display all employees whose names start with a specific letter. Compare the performance with and without the index.

# %% [markdown]
# ### Assignment 10: Backing Up and Restoring Data
#
# 1. Write a Python function to back up the `test.db` database to a file named `backup.db`.

# %% [markdown]
# 2. Write a Python function to restore the `test.db` database from the `backup.db` file.
